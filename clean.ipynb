# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('unclean_data.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv('unclean_data.csv')
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/jupyter-env/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df1 = pd.read_csv('unclean_data.csv', encoding='latin1')
df1.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
df1.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %%
df1.columns = df1.columns.str.upper()
df1.columns
# Out:
# Index(['MOVIE_TITLE', 'NUM_CRITIC_FOR_REVIEWS', 'DURATION',
#        'DIRECTOR_FACEBOOK_LIKES', 'ACTOR_3_FACEBOOK_LIKES',
#        'ACTOR_1_FACEBOOK_LIKES', 'GROSS', 'NUM_VOTED_USERS',
#        'CAST_TOTAL_FACEBOOK_LIKES', 'FACENUMBER_IN_POSTER',
#        'NUM_USER_FOR_REVIEWS', 'BUDGET', 'TITLE_YEAR',
#        'ACTOR_2_FACEBOOK_LIKES', 'IMDB_SCORE', 'TITLE_YEAR.1'],
#       dtype='object')

# %%
df1.rename(columns = {'DURATION': 'TIME'})
# Out:
#                                      MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
df1.isnull()
# Out:
#     MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  DURATION  DIRECTOR_FACEBOOK_LIKES  \
# 0         False                   False     False                    False
# 1         False                   False      True                    False
# 2         False                   False     False                    False
# 3         False                   False      True                    False
# 4         False                   False     False                    False
# 5         False                   False     False                    False
# 6         False                   False      True                    False
# 7         False                   False     False                    False
# 8         False                   False     False                    False
# 9         False                   False     False                    False
# 10        False                   False     False                     True
# ...

# %%
df1.isnull().any()
# Out:
# MOVIE_TITLE                  False
# NUM_CRITIC_FOR_REVIEWS       False
# DURATION                      True
# DIRECTOR_FACEBOOK_LIKES       True
# ACTOR_3_FACEBOOK_LIKES       False
# ACTOR_1_FACEBOOK_LIKES       False
# GROSS                        False
# NUM_VOTED_USERS               True
# CAST_TOTAL_FACEBOOK_LIKES     True
# FACENUMBER_IN_POSTER          True
# NUM_USER_FOR_REVIEWS         False
# BUDGET                       False
# TITLE_YEAR                   False
# ACTOR_2_FACEBOOK_LIKES        True
# IMDB_SCORE                   False
# TITLE_YEAR.1                  True
# dtype: bool

# %%
df1.isnull().sum()
# Out:
# MOVIE_TITLE                  0
# NUM_CRITIC_FOR_REVIEWS       0
# DURATION                     3
# DIRECTOR_FACEBOOK_LIKES      2
# ACTOR_3_FACEBOOK_LIKES       0
# ACTOR_1_FACEBOOK_LIKES       0
# GROSS                        0
# NUM_VOTED_USERS              1
# CAST_TOTAL_FACEBOOK_LIKES    2
# FACENUMBER_IN_POSTER         5
# NUM_USER_FOR_REVIEWS         0
# BUDGET                       0
# TITLE_YEAR                   0
# ACTOR_2_FACEBOOK_LIKES       1
# IMDB_SCORE                   0
# TITLE_YEAR.1                 7
# dtype: int64

# %%
df1.isnull().sum().sum()
# Out:
# 21

# %%
df1.head()
# Out:
#                                   MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    DURATION DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_FACEBOOK_LIKES      GROSS  NUM_VOTED_USERS  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
df_with_0 = df1.fillna(0)
df_with_0.head()
# Out:
#                                   MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    DURATION DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  \
# 0     178.0                      10                     855
# 1       0.0                     563                    1000
# 2     148.0                      20                     161
# 3       0.0                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_FACEBOOK_LIKES      GROSS  NUM_VOTED_USERS  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
df1['DURATION'].mean()
# Out:
# 150.72727272727272

# %%
df_with_mean = df1.fillna(df1['DURATION'].mean())
df_with_mean
# Out:
#                                      MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
df_with_mean.isnull().sum()
# Out:
# MOVIE_TITLE                  0
# NUM_CRITIC_FOR_REVIEWS       0
# DURATION                     0
# DIRECTOR_FACEBOOK_LIKES      0
# ACTOR_3_FACEBOOK_LIKES       0
# ACTOR_1_FACEBOOK_LIKES       0
# GROSS                        0
# NUM_VOTED_USERS              0
# CAST_TOTAL_FACEBOOK_LIKES    0
# FACENUMBER_IN_POSTER         0
# NUM_USER_FOR_REVIEWS         0
# BUDGET                       0
# TITLE_YEAR                   0
# ACTOR_2_FACEBOOK_LIKES       0
# IMDB_SCORE                   0
# TITLE_YEAR.1                 0
# dtype: int64

# %%
df1.shape
# Out:
# (14, 16)

# %%
df_drop = df1.dropna()

# %%
df_drop.shape
# Out:
# (4, 16)

# %%
df_drop
# Out:
#                                      MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  \
# 2                                      Spectre?ÿ                     602
# 8                      Avengers: Age of Ultron?ÿ                     635
# 12                           Quantum of Solace?ÿ                     403
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ                     313
#
#     DURATION DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  \
# 2      148.0                      20                     161
# 8      141.0                      10                   19000
# 12     106.0                     395                     393
# 13     151.0                     563                    1000
#
#     ACTOR_1_FACEBOOK_LIKES      GROSS  NUM_VOTED_USERS  \
# 2                    11000  200074175         275868.0
# 8                    26000  458991599         462669.0
# 12                     451  168368427         330784.0
# 13                   40000  423032628         522040.0
#
# ...

# %%
df_with_condition = df1.dropna(axis=1)
df_with_condition.describe(include=[np.number])
# Out:
#        NUM_CRITIC_FOR_REVIEWS  ACTOR_3_FACEBOOK_LIKES  ACTOR_1_FACEBOOK_LIKES  \
# count               14.000000               14.000000               14.000000
# mean               506.142857             5866.142857            18206.428571
# std                169.069789             8289.592695            13905.214361
# min                302.000000              161.000000              451.000000
# 25%                379.250000              611.250000             3500.000000
# 50%                448.000000             1000.000000            21000.000000
# 75%                635.000000             8500.000000            26000.000000
# max                813.000000            23000.000000            40000.000000
#
#               GROSS  NUM_USER_FOR_REVIEWS        BUDGET   TITLE_YEAR  \
# count  1.400000e+01             14.000000  1.400000e+01    14.000000
# mean   3.335836e+08           1620.071429  2.462643e+08  2010.500000
# ...

# %%
df_with_condition.describe(include='O')
# Out:
#                       MOVIE_TITLE
# count                          14
# unique                         13
# top     Avengers: Age of Ultron?ÿ
# freq                            2

# %%
s = pd.Series(['a', 'b', 'a', 'c'])
dummies = pd.get_dummies(s)
print(dummies)
# Out:
#        a      b      c
# 0   True  False  False
# 1  False   True  False
# 2   True  False  False
# 3  False  False   True

# %%
df = pd.DataFrame({
    'color': ['red', 'blue', 'green', 'red'],
    'size': ['S', 'M', 'L', 'S']
})

# 对 'color' 列进行独热编码
encoded_df = pd.get_dummies(df, columns=['color'])
print(encoded_df)
# Out:
#   size  color_blue  color_green  color_red
# 0    S       False        False       True
# 1    M        True        False      False
# 2    L       False         True      False
# 3    S       False        False       True
